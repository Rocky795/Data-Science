# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Legand Styling

# %%
x=np.arange(0,10)

# %%
a=np.linspace(0,10,11)

# %%
b=a**4

# %%
y=2*x

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])

ax.plot(x,x,label="X vs X")
ax.plot(x,x**2,label="X vs X^2")
ax.legend(loc=(0,1))

# %% [markdown]
# # Visual Syling

# %%
fig=plt.figure()
axes=fig.add_axes([0,0,1,1])

axes.plot(x,x,color="#e6c017",lw=2,ls="--",marker='o',markersize=9)

lines=axes.plot(x,x+2,color="purple",linewidth=2,marker='*',markersize=9)
lines[0].set_dashes([5,2,10,5])
